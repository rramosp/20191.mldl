# %% [markdown]
# ## Experimenta con distintos tipos de señales y redes recurrentes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, TimeDistributed, Activation
import tensorflow as tf
print (tf.__version__)
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
# Out:
# 1.13.1

# %%
def add_noise(x, noise_pct=.1):
    k = (np.max(x)-np.min(x))*noise_pct
    return x + np.random.normal(size=len(x))*k

def timeseries_as_many2one(t, nb_timesteps_in, timelag=1):
    assert timelag>0, "timelag must be >0"
    X,y = [], []
    for i in range(len(t)-nb_timesteps_in-timelag):
        X.append(t[i:i+nb_timesteps_in])
        y.append(t[i+nb_timesteps_in+timelag-1])
    return np.r_[X].reshape(-1, nb_timesteps_in, 1), np.r_[y].reshape(-1,1)

# %% [markdown]
# ## Varias señales de ejemplo
#
# - observa como `s1` contiene una señal y `ns1` tiene la misma señal con ruido añadido
# - experimenta con distintos niveles de ruido `noise_pct`

# %%
t1 = np.linspace(0,60,500)
s1 = np.sin(t1)+np.cos(2*t1)+t1/10
ns1 = add_noise(s1,noise_pct=.05)
plt.figure(figsize=(20,3))
plt.plot(t1,s1)
plt.plot(t1,ns1)

# %% [markdown]
# **una señal un poco más compleja**

# %%
t2 = np.linspace(0,80,500)
s2 = (np.sin(t2)+np.cos(2*t2)*t2/100)**2*np.sin(t2/10)
ns2 = add_noise(s2,noise_pct=.1)
plt.figure(figsize=(20,3))
plt.plot(t2,s2)
plt.plot(t2,ns2)

# %% [markdown]
# **una señal de un dataset: daily exchange rate USD/MXN**

# %%
import pandas as pd
d = pd.read_csv("data/CURRFX-USDMXN.csv.gz")
d.index = pd.to_datetime(d.Date)
d.head()
# Out:
#                   Date       Rate  High (est)  Low (est)
# Date
# 2017-03-16  2017-03-16  19.230000   19.233000  19.198999
# 2017-03-15  2017-03-15  19.232800   19.674500  19.179501
# 2017-03-14  2017-03-14  19.655001   19.721201  19.570400
# 2017-03-13  2017-03-13  19.617201   19.656000  19.538300
# 2017-03-10  2017-03-10  19.597000   19.872601  19.563999

# %%
s3 = d.Rate.values[::-1]
d[["Rate"]].plot(figsize=(20,3))

# %% [markdown]
# ## Construye o carga otras señales temporales

# %% [markdown]
# ## Paso 1: Decide qué tipo de tarea quieres realizar
#
# - _sugerencia_: inicia con una tarea **many to one**
#
# ## Paso 2: Construye el dataset desde la señal
#
# - no te olvides de revisar si los tamaños (`shape`) de los objetos es el adecuado

# %%
X,y = timeseries_as_many2one(ns2, nb_timesteps_in=20, timelag=1)
i = int(len(X)*2./3)
Xtr, ytr = X[:i], y[:i]
Xts, yts = X[i:], y[i:]
Xtr.shape, Xts.shape, ytr.shape, yts.shape
# Out:
# ((319, 20, 1), (160, 20, 1), (319, 1), (160, 1))

# %% [markdown]
# ## Paso 3: Construye el modelo de red recurrente

# %%
def get_many2one_single_layer_LSTM(n_neurons, nb_timesteps_in):
    # create LSTM
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    model = Sequential()
    model.add(LSTM(n_neurons, input_shape=(nb_timesteps_in, 1),recurrent_activation="sigmoid"))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=["mape"])
    return model

# %%
model = get_many2one_single_layer_LSTM(n_neurons=30, nb_timesteps_in=X.shape[1])
# Out:
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %% [markdown]
# ## Pase 4: Entrena tu modelo

# %%
model.fit(Xtr, ytr, epochs=15, batch_size=10, verbose=1, validation_data=(Xts, yts))
# Out:
# Train on 319 samples, validate on 160 samples
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/15
# 319/319 [==============================] - 1s 3ms/sample - loss: 0.4887 - mean_absolute_percentage_error: 2949.8586 - val_loss: 0.6437 - val_mean_absolute_percentage_error: 203.9028
# Epoch 2/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4520 - mean_absolute_percentage_error: 4649.5972 - val_loss: 0.6317 - val_mean_absolute_percentage_error: 230.8943
# Epoch 3/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4465 - mean_absolute_percentage_error: 6455.4434 - val_loss: 0.6342 - val_mean_absolute_percentage_error: 210.2043
# Epoch 4/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4398 - mean_absolute_percentage_error: 4204.5703 - val_loss: 0.6192 - val_mean_absolute_percentage_error: 224.0632
# Epoch 5/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4264 - mean_absolute_percentage_error: 4906.3784 - val_loss: 0.6197 - val_mean_absolute_percentage_error: 242.9220
# Epoch 6/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4199 - mean_absolute_percentage_error: 5816.6616 - val_loss: 0.6285 - val_mean_absolute_percentage_error: 224.5915
# Epoch 7/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4110 - mean_absolute_percentage_error: 4734.3984 - val_loss: 0.6262 - val_mean_absolute_percentage_error: 248.7626
# Epoch 8/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4057 - mean_absolute_percentage_error: 5070.6558 - val_loss: 0.6305 - val_mean_absolute_percentage_error: 245.9115
# Epoch 9/15
# 319/319 [==============================] - 0s 1ms/sample - loss: 0.4005 - mean_absolute_percentage_error: 4982.3833 - val_loss: 0.6428 - val_mean_absolute_percentage_error: 227.3093
# Epoch 10/15
# 319/319 [==============================] - 1s 2ms/sample - loss: 0.3978 - mean_absolute_percentage_error: 4225.9912 - val_loss: 0.6259 - val_mean_absolute_percentage_error: 279.6304
# Epoch 11/15
# 319/319 [==============================] - 1s 2ms/sample - loss: 0.3960 - mean_absolute_percentage_error: 6458.1699 - val_loss: 0.6338 - val_mean_absolute_percentage_error: 228.3102
# Epoch 12/15
# 319/319 [==============================] - 1s 2ms/sample - loss: 0.3988 - mean_absolute_percentage_error: 3665.4768 - val_loss: 0.6247 - val_mean_absolute_percentage_error: 279.3093
# Epoch 13/15
# 319/319 [==============================] - 0s 2ms/sample - loss: 0.3919 - mean_absolute_percentage_error: 6292.5044 - val_loss: 0.6303 - val_mean_absolute_percentage_error: 238.3355
# Epoch 14/15
# 319/319 [==============================] - 1s 2ms/sample - loss: 0.3947 - mean_absolute_percentage_error: 5127.4951 - val_loss: 0.6084 - val_mean_absolute_percentage_error: 263.1015
# Epoch 15/15
# 319/319 [==============================] - 1s 2ms/sample - loss: 0.3926 - mean_absolute_percentage_error: 4399.2656 - val_loss: 0.6121 - val_mean_absolute_percentage_error: 246.3239

# %% [markdown]
# ## Paso 5: Mide desempeño y pinta la salida

# %%
yts_preds = model.predict(Xts)
yts_preds.shape
print ("trend accuracy %.2f"%(np.mean( (yts_preds[1:]>yts_preds[:-1])==(yts[1:]>yts[:-1]))))
# Out:
# trend accuracy 0.40

# %%
plt.figure(figsize=(15,3))
plt.plot(yts[:,0], color="red", alpha=.3, lw=5, label="target")
plt.plot(yts_preds[:,0], color="red", alpha=1, lw=2, label="prediction")
plt.legend()
plt.grid()

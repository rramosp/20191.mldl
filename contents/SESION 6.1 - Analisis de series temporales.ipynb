# %% [markdown]
# # Series temporales
#
# - [Understanding LSTM Networks](https://colah.github.io/posts/2015-08-Understanding-LSTMs/)
# - [Keras LSTM Tutorial](http://adventuresinmachinelearning.com/keras-lstm-tutorial/)
# - [Visual Analysis for Recurrent Neural Networks](http://lstm.seas.harvard.edu/client/index.html)
# - [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)

# %%
import pandas, numpy, time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, LSTM
from tensorflow.keras.backend import clear_session

# %%
# convert an array of values into a sliding window dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

def get_predictions(model, scaler, kX, y=None):
    """
    y: not used in prediction, only to get the transformation back
    """
    s_preds = model.predict(kX)
    if scaler is not None:
        s_preds = scaler.inverse_transform(s_preds)
        
    if y is not None:
        s_y     = scaler.inverse_transform(y) if scaler is not None else y
        return s_y[0], s_preds[:,0]
    else:
        return s_preds

def get_RMSE(model, scaler, kX, y):

    sy,spreds = get_predictions(model, scaler, kX, y)
    return np.sqrt(np.mean((sy-spreds)**2))

def plot_predictions(dataset, ktrainX, trainY, ktestX, testY, model, scaler, look_back):
    sy_train, spreds_train = get_predictions(model, scaler, ktrainX, [trainY])
    sy_test,  spreds_test  = get_predictions(model, scaler, ktestX, [testY])
    
    plt.figure(figsize=(20,5))
    plt.plot(range(look_back, look_back+len(spreds_train)), spreds_train,
            label="predictions train", color="blue", lw=2)
    plt.plot(range(look_back, look_back+len(spreds_train)), sy_train,
            label="target train", color="blue", lw=2, alpha=.3)

    plt.plot(range(look_back+len(spreds_train), look_back+len(spreds_train)+len(spreds_test)), 
             spreds_test, label="predictions test", color="red", lw=2)
    plt.plot(range(look_back+len(spreds_train), look_back+len(spreds_train)+len(spreds_test)), 
             sy_test,         
             label="target test", color="red", lw=2, alpha=.3)
    
    plt.plot(scaler.inverse_transform(dataset), color="black", label="data", lw=3, alpha=.2)
    plt.legend(loc=2)
    plt.xlim(0,len(dataset))
    plt.xticks(range(0,len(dataset),2));
    plt.grid()

    
def get_model(lstm_size, input_shape):
    clear_session()
    model = Sequential()
    lstm = LSTM(units=lstm_size, input_shape=input_shape, recurrent_activation="sigmoid")
    dense = Dense(1)
    model.add(lstm)
    model.add(dense)
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model
    
def rnn_experiment(dataset, look_back, lstm_size, batch_size, epochs, scaler, pct_train=0.67):

    train_size  = int(len(dataset) * 0.67)
    test_size   = len(dataset) - train_size
    train, test = dataset[0:train_size,:], dataset[train_size-look_back:len(dataset),:]    
    
    trainX, trainY = create_dataset(train, look_back)
    testX, testY   = create_dataset(test, look_back)
    ktrainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1],1))
    ktestX  = numpy.reshape(testX, (testX.shape[0], testX.shape[1],1))

    print ("building RNN",end=" ")
    model = get_model(lstm_size, ktrainX.shape[1:])
    print ("fitting RNN")
    mhist = model.fit(ktrainX, trainY, epochs=epochs, batch_size=batch_size, verbose=0)

    sy_train, spreds_train = get_predictions(model, scaler, ktrainX, [trainY])
    sy_test,  spreds_test  = get_predictions(model, scaler, ktestX, [testY])
    print ("train score: %.2f RMSE"%get_RMSE(model, scaler, ktrainX, [trainY]))
    print ("test score:  %.2f RMSE"%get_RMSE(model, scaler, ktestX, [testY]))
        
    y, preds         = sy_test, spreds_test
    y_delta, p_delta = (y[1:]>y[:-1]), preds[1:]>preds[:-1]
    print ("trend prediction accuracy (test)  %.2f"%np.mean(y_delta==p_delta))

    y, preds         = sy_train, spreds_train
    y_delta, p_delta = (y[1:]>y[:-1]), preds[1:]>preds[:-1]
    print ("trend prediction accuracy (train) %.2f"%np.mean(y_delta==p_delta))
    
    plot_predictions(dataset, ktrainX, trainY, ktestX, testY, model, scaler, look_back)

# %% [markdown]
# ## 1. load and preprocess dataset
#
# - example and dataset obtained from [Time series prediction with LSTM Recurrent Neural Networks in Python with Keras](http://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/)
#
# - dataset is scaled to [0,1]

# %%
dataset = pd.read_csv('data/international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)
dataset = dataset.values
dataset = dataset.astype('float32')
plt.figure(figsize=(15,2))
plt.plot(dataset)

# %%
np.random.seed()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
plt.figure(figsize=(15,2))
plt.plot(dataset)

# %% [markdown]
# ### split original signal into train and test

# %%
look_back=3

train_size  = int(len(dataset) * 0.67)
test_size   = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size-look_back:len(dataset),:]
print (train.shape, test.shape)
# Out:
# (96, 1) (51, 1)

# %% [markdown]
# ### creating time framed dataset
#
# - reshape into $X=[x_{t-n},..., x_{t-1}, x_t]$ and $Y=x_{t+1}$
# - reshape for Keras into 3D array (as for multiple signals although in this case we only use one signal)

# %%
trainX, trainY = create_dataset(train, look_back)
testX, testY   = create_dataset(test, look_back)
ktrainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1],1))
ktestX  = numpy.reshape(testX, (testX.shape[0], testX.shape[1],1))

# %%
print ("full original signal     ", dataset.shape)
print ("original signal     train", train.shape, "test", test.shape)
print ("time framed signal  train", trainX.shape, "test", testX.shape)
print ("keras input signal  train", ktrainX.shape, "test", ktestX.shape)
# Out:
# full original signal      (144, 1)
# original signal     train (96, 1) test (51, 1)
# time framed signal  train (93, 3) test (48, 3)
# keras input signal  train (93, 3, 1) test (48, 3, 1)

# %%
print (train[:10,0])
print (trainX[:5])
print (trainY[:5])
# Out:
# [0.01544401 0.02702703 0.05405405 0.04826255 0.03281853 0.05984557
#  0.08494207 0.08494207 0.06177607 0.02895753]
# [[0.01544401 0.02702703 0.05405405]
#  [0.02702703 0.05405405 0.04826255]
#  [0.05405405 0.04826255 0.03281853]
#  [0.04826255 0.03281853 0.05984557]
#  [0.03281853 0.05984557 0.08494207]]
# [0.04826255 0.03281853 0.05984557 0.08494207 0.08494207]

# %% [markdown]
# ### podríamos usar cual método de ML con este dataset

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(trainX, trainY)
# Out:
# /home/user/.conda/envs/p37/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
plt.plot(testY)
plt.plot(rf.predict(testX))

# %% [markdown]
# ## 2. RNN definition and fitting

# %%
## build RNN

model = get_model(50, input_shape=[3,1])
clear_session()
model = Sequential()
lstm = LSTM(units=50, input_shape=[3,1], recurrent_activation="sigmoid")
dense = Dense(1)
model.add(lstm)
model.add(dense)
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
trainY
# Out:
# array([0.04826255, 0.03281853, 0.05984557, 0.08494207, 0.08494207,
#        0.06177607, 0.02895753, 0.        , 0.02702703, 0.02123553,
#        0.04247104, 0.07142857, 0.05984557, 0.04054055, 0.08687258,
#        0.12741312, 0.12741312, 0.10424709, 0.05598456, 0.01930502,
#        0.06949806, 0.07915059, 0.08880308, 0.14285713, 0.11389962,
#        0.13127413, 0.14285713, 0.18339768, 0.18339768, 0.15444016,
#        0.11196911, 0.08108109, 0.1196911 , 0.12934363, 0.14671814,
#        0.17181468, 0.14864865, 0.15250966, 0.22007722, 0.24324325,
#        0.26640925, 0.2027027 , 0.16795367, 0.13127413, 0.17374519,
#        0.17760617, 0.17760617, 0.25482625, 0.25289574, 0.24131274,
#        0.26833975, 0.3088803 , 0.32432434, 0.25675675, 0.20656371,
#        0.14671814, 0.18725869, 0.19305018, 0.16216215, 0.25289574,
#        0.23745173, 0.25096524, 0.3088803 , 0.38223937, 0.36486486,
#        0.2992278 , 0.24131274, 0.1911197 , 0.24131274, 0.26640925,
#        0.24903473, 0.31467178, 0.3185328 , 0.32046333, 0.4073359 ,
#        0.5019305 , 0.46911195, 0.40154442, 0.32818535, 0.25675675,
#        0.3359073 , 0.34749034, 0.33397684, 0.41119692, 0.4034749 ,
#        0.4131274 , 0.52123547, 0.5965251 , 0.58108103, 0.484556  ,
#        0.3899614 , 0.3223938 , 0.3899614 ], dtype=float32)

# %%
mhist = model.fit(ktrainX, trainY, epochs=100, batch_size=10, verbose=1)
# Out:
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 93/93 [==============================] - 1s 11ms/sample - loss: 0.0604
# Epoch 2/100
# 93/93 [==============================] - 0s 436us/sample - loss: 0.0291
# Epoch 3/100
# 93/93 [==============================] - 0s 387us/sample - loss: 0.0149
# Epoch 4/100
# 93/93 [==============================] - 0s 412us/sample - loss: 0.0106
# Epoch 5/100
# 93/93 [==============================] - 0s 415us/sample - loss: 0.0100
# Epoch 6/100
# 93/93 [==============================] - 0s 525us/sample - loss: 0.0089
# Epoch 7/100
# 93/93 [==============================] - 0s 436us/sample - loss: 0.0081
# Epoch 8/100
# 93/93 [==============================] - 0s 417us/sample - loss: 0.0074
# Epoch 9/100
# 93/93 [==============================] - 0s 446us/sample - loss: 0.0067
# Epoch 10/100
# 93/93 [==============================] - 0s 442us/sample - loss: 0.0062
# Epoch 11/100
# 93/93 [==============================] - 0s 431us/sample - loss: 0.0058
# Epoch 12/100
# 93/93 [==============================] - 0s 674us/sample - loss: 0.0053
# Epoch 13/100
# 93/93 [==============================] - 0s 526us/sample - loss: 0.0051
# Epoch 14/100
# 93/93 [==============================] - 0s 434us/sample - loss: 0.0048
# Epoch 15/100
# 93/93 [==============================] - 0s 450us/sample - loss: 0.0048
# Epoch 16/100
# 93/93 [==============================] - 0s 384us/sample - loss: 0.0048
# Epoch 17/100
# 93/93 [==============================] - 0s 432us/sample - loss: 0.0048
# Epoch 18/100
# 93/93 [==============================] - 0s 446us/sample - loss: 0.0046
# Epoch 19/100
# 93/93 [==============================] - 0s 420us/sample - loss: 0.0046
# Epoch 20/100
# 93/93 [==============================] - 0s 478us/sample - loss: 0.0046
# Epoch 21/100
# 93/93 [==============================] - 0s 430us/sample - loss: 0.0046
# Epoch 22/100
# 93/93 [==============================] - 0s 375us/sample - loss: 0.0046
# Epoch 23/100
# 93/93 [==============================] - 0s 455us/sample - loss: 0.0044
# Epoch 24/100
# 93/93 [==============================] - 0s 400us/sample - loss: 0.0045
# Epoch 25/100
# 93/93 [==============================] - 0s 419us/sample - loss: 0.0044
# Epoch 26/100
# 93/93 [==============================] - 0s 367us/sample - loss: 0.0044
# Epoch 27/100
# 93/93 [==============================] - 0s 385us/sample - loss: 0.0044
# Epoch 28/100
# 93/93 [==============================] - 0s 437us/sample - loss: 0.0046
# Epoch 29/100
# 93/93 [==============================] - 0s 400us/sample - loss: 0.0043
# Epoch 30/100
# 93/93 [==============================] - 0s 527us/sample - loss: 0.0045
# Epoch 31/100
# 93/93 [==============================] - 0s 452us/sample - loss: 0.0044
# Epoch 32/100
# 93/93 [==============================] - 0s 473us/sample - loss: 0.0044
# Epoch 33/100
# 93/93 [==============================] - 0s 506us/sample - loss: 0.0042
# Epoch 34/100
# 93/93 [==============================] - 0s 518us/sample - loss: 0.0045
# Epoch 35/100
# 93/93 [==============================] - 0s 509us/sample - loss: 0.0041
# Epoch 36/100
# 93/93 [==============================] - 0s 510us/sample - loss: 0.0043
# Epoch 37/100
# 93/93 [==============================] - 0s 509us/sample - loss: 0.0042
# Epoch 38/100
# 93/93 [==============================] - 0s 475us/sample - loss: 0.0042
# Epoch 39/100
# 93/93 [==============================] - 0s 440us/sample - loss: 0.0041
# Epoch 40/100
# 93/93 [==============================] - 0s 373us/sample - loss: 0.0042
# Epoch 41/100
# 93/93 [==============================] - 0s 429us/sample - loss: 0.0041
# Epoch 42/100
# 93/93 [==============================] - 0s 381us/sample - loss: 0.0042
# Epoch 43/100
# 93/93 [==============================] - 0s 397us/sample - loss: 0.0042
# Epoch 44/100
# 93/93 [==============================] - 0s 406us/sample - loss: 0.0043
# Epoch 45/100
# 93/93 [==============================] - 0s 441us/sample - loss: 0.0041
# Epoch 46/100
# 93/93 [==============================] - 0s 438us/sample - loss: 0.0040
# Epoch 47/100
# 93/93 [==============================] - 0s 422us/sample - loss: 0.0040
# Epoch 48/100
# 93/93 [==============================] - 0s 389us/sample - loss: 0.0041
# Epoch 49/100
# 93/93 [==============================] - 0s 380us/sample - loss: 0.0040
# Epoch 50/100
# 93/93 [==============================] - 0s 450us/sample - loss: 0.0040
# Epoch 51/100
# 93/93 [==============================] - 0s 398us/sample - loss: 0.0039
# Epoch 52/100
# 93/93 [==============================] - 0s 444us/sample - loss: 0.0040
# Epoch 53/100
# 93/93 [==============================] - 0s 406us/sample - loss: 0.0039
# Epoch 54/100
# 93/93 [==============================] - 0s 425us/sample - loss: 0.0039
# Epoch 55/100
# 93/93 [==============================] - 0s 389us/sample - loss: 0.0039
# Epoch 56/100
# 93/93 [==============================] - 0s 422us/sample - loss: 0.0039
# Epoch 57/100
# 93/93 [==============================] - 0s 515us/sample - loss: 0.0039
# Epoch 58/100
# 93/93 [==============================] - 0s 582us/sample - loss: 0.0038
# Epoch 59/100
# 93/93 [==============================] - 0s 635us/sample - loss: 0.0039
# Epoch 60/100
# 93/93 [==============================] - 0s 795us/sample - loss: 0.0038
# Epoch 61/100
# 93/93 [==============================] - 0s 820us/sample - loss: 0.0038
# Epoch 62/100
# 93/93 [==============================] - 0s 495us/sample - loss: 0.0042
# Epoch 63/100
# 93/93 [==============================] - 0s 432us/sample - loss: 0.0039
# Epoch 64/100
# 93/93 [==============================] - 0s 328us/sample - loss: 0.0037
# Epoch 65/100
# 93/93 [==============================] - 0s 440us/sample - loss: 0.0037
# Epoch 66/100
# 93/93 [==============================] - 0s 387us/sample - loss: 0.0038
# Epoch 67/100
# 93/93 [==============================] - 0s 427us/sample - loss: 0.0038
# Epoch 68/100
# 93/93 [==============================] - 0s 420us/sample - loss: 0.0037
# Epoch 69/100
# 93/93 [==============================] - 0s 412us/sample - loss: 0.0037
# Epoch 70/100
# 93/93 [==============================] - 0s 361us/sample - loss: 0.0036
# Epoch 71/100
# 93/93 [==============================] - 0s 394us/sample - loss: 0.0036
# Epoch 72/100
# 93/93 [==============================] - 0s 395us/sample - loss: 0.0036
# Epoch 73/100
# 93/93 [==============================] - 0s 379us/sample - loss: 0.0035
# Epoch 74/100
# 93/93 [==============================] - 0s 398us/sample - loss: 0.0035
# Epoch 75/100
# 93/93 [==============================] - 0s 377us/sample - loss: 0.0035
# Epoch 76/100
# 93/93 [==============================] - 0s 397us/sample - loss: 0.0036
# Epoch 77/100
# 93/93 [==============================] - 0s 908us/sample - loss: 0.0035
# Epoch 78/100
# 93/93 [==============================] - 0s 661us/sample - loss: 0.0034
# Epoch 79/100
# 93/93 [==============================] - 0s 562us/sample - loss: 0.0035
# Epoch 80/100
# 93/93 [==============================] - 0s 387us/sample - loss: 0.0035
# Epoch 81/100
# 93/93 [==============================] - 0s 362us/sample - loss: 0.0034
# Epoch 82/100
# 93/93 [==============================] - 0s 346us/sample - loss: 0.0034
# Epoch 83/100
# 93/93 [==============================] - 0s 372us/sample - loss: 0.0034
# Epoch 84/100
# 93/93 [==============================] - 0s 388us/sample - loss: 0.0034
# Epoch 85/100
# 93/93 [==============================] - 0s 404us/sample - loss: 0.0033
# Epoch 86/100
# 93/93 [==============================] - 0s 386us/sample - loss: 0.0034
# Epoch 87/100
# 93/93 [==============================] - 0s 367us/sample - loss: 0.0033
# Epoch 88/100
# 93/93 [==============================] - 0s 423us/sample - loss: 0.0034
# Epoch 89/100
# 93/93 [==============================] - 0s 389us/sample - loss: 0.0032
# Epoch 90/100
# 93/93 [==============================] - 0s 614us/sample - loss: 0.0033
# Epoch 91/100
# 93/93 [==============================] - 0s 580us/sample - loss: 0.0032
# Epoch 92/100
# 93/93 [==============================] - 0s 341us/sample - loss: 0.0033
# Epoch 93/100
# 93/93 [==============================] - 0s 383us/sample - loss: 0.0032
# Epoch 94/100
# 93/93 [==============================] - 0s 388us/sample - loss: 0.0032
# Epoch 95/100
# 93/93 [==============================] - 0s 409us/sample - loss: 0.0032
# Epoch 96/100
# 93/93 [==============================] - 0s 420us/sample - loss: 0.0031
# Epoch 97/100
# 93/93 [==============================] - 0s 412us/sample - loss: 0.0031
# Epoch 98/100
# 93/93 [==============================] - 0s 410us/sample - loss: 0.0031
# Epoch 99/100
# 93/93 [==============================] - 0s 385us/sample - loss: 0.0032
# Epoch 100/100
# 93/93 [==============================] - 0s 354us/sample - loss: 0.0031

# %%
plt.figure(figsize=(15,3))
plt.plot(mhist.history["loss"], label="loss")
plt.xlabel("train epoch")
plt.legend()

# %% [markdown]
# ### compute and visualize predictions and errors

# %%
sy_train, spreds_train = get_predictions(model, scaler, ktrainX, [trainY])
sy_test,  spreds_test  = get_predictions(model, scaler, ktestX, [testY])
print ("train score: %.2f RMSE"%get_RMSE(model, scaler, ktrainX, [trainY]))
print ("test score:  %.2f RMSE"%get_RMSE(model, scaler, ktestX, [testY]))

y, preds         = sy_test, spreds_test
y_delta, p_delta = (y[1:]>y[:-1]), preds[1:]>preds[:-1]
print ("trend prediction accuracy (test)  %.2f"%np.mean(y_delta==p_delta))

y, preds         = sy_train, spreds_train
y_delta, p_delta = (y[1:]>y[:-1]), preds[1:]>preds[:-1]
print ("trend prediction accuracy (train) %.2f"%np.mean(y_delta==p_delta))

plot_predictions(dataset, ktrainX, trainY, ktestX, testY, model, scaler, look_back)
# Out:
# train score: 28.47 RMSE
# test score:  61.67 RMSE
# trend prediction accuracy (test)  0.57
# trend prediction accuracy (train) 0.55

# %% [markdown]
# ### compute trend prediction error (up or down)

# %%
y = sy_test
preds = spreds_test
print ("RMSE (check) %.2f"%np.sqrt(np.mean((y-preds)**2)))

y_delta = (y[1:]>y[:-1])
p_delta = preds[1:]>preds[:-1]
print ("trend prediction accuracy %.2f"%np.mean(y_delta==p_delta))
# Out:
# RMSE (check) 61.67
# trend prediction accuracy 0.57

# %% [markdown]
# ## 4. Fine tune RNN
#
# observe with the network such as above, predictions can be seen as the input delayed ... so it is not really learning much

# %%
rnn_experiment(dataset, look_back=3, lstm_size=50, batch_size=10, epochs=200, scaler=scaler)
# Out:
# building RNN fitting RNN
# train score: 23.21 RMSE
# test score:  62.13 RMSE
# trend prediction accuracy (test)  0.55
# trend prediction accuracy (train) 0.51

# %% [markdown]
# try out with different parameters

# %%
rnn_experiment(dataset, look_back=20, lstm_size=5, batch_size=10, epochs=200, scaler=scaler)
# Out:
# building RNN fitting RNN
# train score: 31.19 RMSE
# test score:  67.35 RMSE
# trend prediction accuracy (test)  0.55
# trend prediction accuracy (train) 0.57

# %%
rnn_experiment(dataset, look_back=20, lstm_size=5, batch_size=10, epochs=150, scaler=scaler)
# Out:
# building RNN fitting RNN
# train score: 33.34 RMSE
# test score:  90.47 RMSE
# trend prediction accuracy (test)  0.57
# trend prediction accuracy (train) 0.48

# %%
rnn_experiment(dataset, look_back=20, lstm_size=30, batch_size=10, epochs=150, scaler=scaler)
# Out:
# building RNN fitting RNN
# train score: 20.61 RMSE
# test score:  56.15 RMSE
# trend prediction accuracy (test)  0.74
# trend prediction accuracy (train) 0.69

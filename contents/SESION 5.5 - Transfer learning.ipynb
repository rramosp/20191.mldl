# %%
import tensorflow as tf
from time import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mlutils
import pickle
# %matplotlib inline

# %% [markdown]
# ## Observa los filtros de primer nivel de AlexNet
#
# Red Preentrenada: https://www.cs.toronto.edu/~guerzhoy/tf_alexnet/
#
# Paper: [ImageNet Classification with Deep Convolutional Neural Networks](https://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf)
#
# [Large Scale Visual Recognition Challenge 2012](http://www.image-net.org/challenges/LSVRC/2012/)
#
# [ImageNet](http://www.image-net.org)

# %%
alex_w1 = pickle.load( open( "data/alexnet_w1.pkl", "rb" ), encoding="bytes" )
print (alex_w1.shape)
mlutils.display_imgs(alex_w1)
# Out:
# (11, 11, 3, 96)

# %% [markdown]
# ### Vamos a usarlos como punto de partida para el entrenamiento de nuestra red

# %%
# !wget -nc https://s3.amazonaws.com/rlx/mini_cifar.h5
# Out:
# File ‘mini_cifar.h5’ already there; not retrieving.

# %%
import h5py
with h5py.File('mini_cifar.h5','r') as h5f:
    x_cifar = h5f["x"][:]
    y_cifar = h5f["y"][:]

# %%
mlutils.show_labeled_image_mosaic(x_cifar, y_cifar)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_cifar, y_cifar, test_size=.25)
print (x_train.shape, y_train.shape, x_test.shape, y_test.shape)
print ("\ndistribution of train classes")
print (pd.Series(y_train).value_counts())
print ("\ndistribution of test classes")
print (pd.Series(y_test).value_counts())
# Out:
# (2253, 32, 32, 3) (2253,) (751, 32, 32, 3) (751,)
#
# distribution of train classes
# 2    799
# 0    733
# 1    721
# dtype: int64
#
# distribution of test classes
# 0    272
# 1    253
# 2    226
# dtype: int64

# %%
def get_conv_model_C(num_classes, img_size=32, compile=True):
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print ("using",num_classes,"classes")
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(96,(11,11), activation="relu")(inputs)
    layers = tf.keras.layers.MaxPool2D((2,2))(layers)
    layers = tf.keras.layers.Conv2D(60,(11,11), activation="relu")(layers)
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(16, activation=tf.nn.relu)(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
    return model

# %%
def train(model, batch_size, epochs, model_name=""):
    tensorboard = tf.keras.callbacks.TensorBoard(log_dir="logs/"+model_name+"_"+"{}".format(time()))
    model.reset_states()
    model.fit(x_train, y_train, epochs=epochs, callbacks=[tensorboard],
              batch_size=batch_size,
              validation_data=(x_test, y_test))
    metrics = model.evaluate(x_test, y_test)
    return {k:v for k,v in zip (model.metrics_names, metrics)}

# %%
num_classes = len(np.unique(y_cifar))
model = get_conv_model_C(num_classes)
model.summary()
# Out:
# using 3 classes
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 22, 22, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 11, 11, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 1, 1, 60)          697020
# _________________________________________________________________
# flatten (Flatten)            (None, 60)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                976
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# output_1 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 732,991
# Trainable params: 732,991
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Transfer learning!!!
#
# - Importamos el valor de los filtros de primer nivel

# %%
w = model.get_weights()
for i in w:
    print (i.shape)
# Out:
# (11, 11, 3, 96)
# (96,)
# (11, 11, 96, 60)
# (60,)
# (60, 16)
# (16,)
# (16, 3)
# (3,)

# %%
w[0] = alex_w1
mlutils.display_imgs(w[0])

# %%
model.set_weights(w)

# %%
train(model, batch_size=32, epochs=10, model_name="model_C")
# Out:
# Train on 2253 samples, validate on 751 samples
# Epoch 1/10
# 2253/2253 [==============================] - 11s 5ms/sample - loss: 0.9095 - acc: 0.5477 - val_loss: 0.7106 - val_acc: 0.6804
# Epoch 2/10
# 2253/2253 [==============================] - 13s 6ms/sample - loss: 0.6915 - acc: 0.7031 - val_loss: 0.6295 - val_acc: 0.7310
# Epoch 3/10
# 2253/2253 [==============================] - 14s 6ms/sample - loss: 0.5883 - acc: 0.7519 - val_loss: 0.6117 - val_acc: 0.7403
# Epoch 4/10
# 2253/2253 [==============================] - 15s 7ms/sample - loss: 0.5389 - acc: 0.7674 - val_loss: 0.6265 - val_acc: 0.7377
# Epoch 5/10
# 2253/2253 [==============================] - 14s 6ms/sample - loss: 0.4893 - acc: 0.8060 - val_loss: 0.5979 - val_acc: 0.7443
# Epoch 6/10
# 2253/2253 [==============================] - 16s 7ms/sample - loss: 0.4379 - acc: 0.8145 - val_loss: 0.6350 - val_acc: 0.7497
# Epoch 7/10
# 2253/2253 [==============================] - 13s 6ms/sample - loss: 0.4052 - acc: 0.8380 - val_loss: 0.7147 - val_acc: 0.7244
# Epoch 8/10
# 2253/2253 [==============================] - 19s 8ms/sample - loss: 0.3674 - acc: 0.8593 - val_loss: 0.5950 - val_acc: 0.7603
# Epoch 9/10
# 2253/2253 [==============================] - 14s 6ms/sample - loss: 0.3156 - acc: 0.8700 - val_loss: 0.6107 - val_acc: 0.7696
# Epoch 10/10
# 2253/2253 [==============================] - 14s 6ms/sample - loss: 0.2840 - acc: 0.8895 - val_loss: 0.7612 - val_acc: 0.7430
# 751/751 [==============================] - 1s 2ms/sample - loss: 0.7612 - acc: 0.7430
# {'loss': 0.7611613801212984, 'acc': 0.7430093}

# %% [markdown]
# observa que los filtros de primer nivel cambiaron, pero muy poco

# %%
w0 = model.get_weights()[0]
np.mean(np.abs(w0-alex_w1))
# Out:
# 0.01240117

# %%
mlutils.display_imgs(w[0])

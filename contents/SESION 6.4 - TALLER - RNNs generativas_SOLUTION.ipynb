# %% [markdown]
# ## TALLER -- inyecta la predicción como último elemento para una nueva entrada, generando así una señal nueva

# %%
import pandas, numpy, time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, LSTM
from tensorflow.keras.backend import clear_session

# %%
# convert an array of values into a sliding window dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

def get_predictions(model, scaler, kX, y=None):
    """
    y: not used in prediction, only to get the transformation back
    """
    s_preds = model.predict(kX)
    if scaler is not None:
        s_preds = scaler.inverse_transform(s_preds)
        
    if y is not None:
        s_y     = scaler.inverse_transform(y) if scaler is not None else y
        return s_y[0], s_preds[:,0]
    else:
        return s_preds

def get_RMSE(model, scaler, kX, y):

    sy,spreds = get_predictions(model, scaler, kX, y)
    return np.sqrt(np.mean((sy-spreds)**2))

def plot_predictions(dataset, ktrainX, trainY, ktestX, testY, model, scaler, look_back):
    sy_train, spreds_train = get_predictions(model, scaler, ktrainX, [trainY])
    sy_test,  spreds_test  = get_predictions(model, scaler, ktestX, [testY])
    
    plt.figure(figsize=(20,5))
    plt.plot(range(look_back, look_back+len(spreds_train)), spreds_train,
            label="predictions train", color="blue", lw=2)
    plt.plot(range(look_back, look_back+len(spreds_train)), sy_train,
            label="target train", color="blue", lw=2, alpha=.3)

    plt.plot(range(look_back+len(spreds_train), look_back+len(spreds_train)+len(spreds_test)), 
             spreds_test, label="predictions test", color="red", lw=2)
    plt.plot(range(look_back+len(spreds_train), look_back+len(spreds_train)+len(spreds_test)), 
             sy_test,         
             label="target test", color="red", lw=2, alpha=.3)
    
    plt.plot(scaler.inverse_transform(dataset), color="black", label="data", lw=3, alpha=.2)
    plt.legend(loc=2)
    plt.xlim(0,len(dataset))
    plt.xticks(range(0,len(dataset),2));
    plt.grid()

    
def get_model(lstm_size, input_shape):
    clear_session()
    model = Sequential()
    lstm = LSTM(units=lstm_size, input_shape=input_shape, recurrent_activation="sigmoid")
    dense = Dense(1)
    model.add(lstm)
    model.add(dense)
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
dataset = pd.read_csv('data/international-airline-passengers.csv', usecols=[1], engine='python', skipfooter=3)
dataset = dataset.values
dataset = dataset.astype('float32')
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
plt.figure(figsize=(15,2))
plt.plot(dataset)

# %%
look_back = 20

train_size  = int(len(dataset) * 0.67)
test_size   = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size-look_back:len(dataset),:]
print (train.shape, test.shape)

trainX, trainY = create_dataset(train, look_back)
testX, testY   = create_dataset(test, look_back)
ktrainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1],1))
ktestX  = numpy.reshape(testX, (testX.shape[0], testX.shape[1],1))
# Out:
# (96, 1) (68, 1)

# %%
model = get_model(50, input_shape=ktestX.shape[1:])
mhist = model.fit(ktrainX, trainY, epochs=200, batch_size=10, verbose=1)
# Out:
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/200
# 76/76 [==============================] - 1s 12ms/sample - loss: 0.0788
# Epoch 2/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0203
# Epoch 3/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0113
# Epoch 4/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0074
# Epoch 5/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0079
# Epoch 6/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0068
# Epoch 7/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0063
# Epoch 8/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0060
# Epoch 9/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0056
# Epoch 10/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0053
# Epoch 11/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0052
# Epoch 12/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0051
# Epoch 13/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0050
# Epoch 14/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0051
# Epoch 15/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0048
# Epoch 16/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0052
# Epoch 17/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0051
# Epoch 18/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0049
# Epoch 19/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0049
# Epoch 20/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0049
# Epoch 21/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0049
# Epoch 22/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0050
# Epoch 23/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0050
# Epoch 24/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0051
# Epoch 25/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0048
# Epoch 26/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0051
# Epoch 27/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0048
# Epoch 28/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0049
# Epoch 29/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0050
# Epoch 30/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0048
# Epoch 31/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0047
# Epoch 32/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0047
# Epoch 33/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0047
# Epoch 34/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0048
# Epoch 35/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0048
# Epoch 36/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0045
# Epoch 37/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0046
# Epoch 38/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0045
# Epoch 39/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0045
# Epoch 40/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0044
# Epoch 41/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0044
# Epoch 42/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0046
# Epoch 43/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0044
# Epoch 44/200
# 76/76 [==============================] - 0s 5ms/sample - loss: 0.0043
# Epoch 45/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0045
# Epoch 46/200
# 76/76 [==============================] - 0s 5ms/sample - loss: 0.0049
# Epoch 47/200
# 76/76 [==============================] - 0s 5ms/sample - loss: 0.0041
# Epoch 48/200
# 76/76 [==============================] - 0s 5ms/sample - loss: 0.0044
# Epoch 49/200
# 76/76 [==============================] - 0s 5ms/sample - loss: 0.0042
# Epoch 50/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0041
# Epoch 51/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0043
# Epoch 52/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0041
# Epoch 53/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0041
# Epoch 54/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0040
# Epoch 55/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0042
# Epoch 56/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0041
# Epoch 57/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0038
# Epoch 58/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0038
# Epoch 59/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0038
# Epoch 60/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0036
# Epoch 61/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0036
# Epoch 62/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0031
# Epoch 63/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0029
# Epoch 64/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0025
# Epoch 65/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0024
# Epoch 66/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0024
# Epoch 67/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0023
# Epoch 68/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0026
# Epoch 69/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0023
# Epoch 70/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0024
# Epoch 71/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0020
# Epoch 72/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0020
# Epoch 73/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0022
# Epoch 74/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 75/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 76/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0022
# Epoch 77/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0023
# Epoch 78/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 79/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0019
# Epoch 80/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0020
# Epoch 81/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 82/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 83/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0022
# Epoch 84/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0021
# Epoch 85/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 86/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 87/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 88/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0019
# Epoch 89/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 90/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0019
# Epoch 91/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 92/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 93/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 94/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 95/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 96/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 97/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 98/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 99/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 100/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 101/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 102/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 103/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 104/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 105/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 106/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 107/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 108/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 109/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 110/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 111/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0019
# Epoch 112/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 113/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0018
# Epoch 114/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 115/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 116/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 117/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 118/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 119/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 120/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 121/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 122/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 123/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 124/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 125/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 126/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 127/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 128/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 129/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 130/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 131/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 132/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 133/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 134/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0016
# Epoch 135/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0016
# Epoch 136/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0016
# Epoch 137/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 138/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0015
# Epoch 139/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 140/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 141/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 142/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 143/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0015
# Epoch 144/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 145/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 146/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 147/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 148/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 149/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0018
# Epoch 150/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0018
# Epoch 151/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0018
# Epoch 152/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 153/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 154/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 155/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 156/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 157/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0016
# Epoch 158/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0016
# Epoch 159/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 160/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 161/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 162/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0015
# Epoch 163/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 164/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0020
# Epoch 165/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0019
# Epoch 166/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 167/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0019
# Epoch 168/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0019
# Epoch 169/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 170/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0015
# Epoch 171/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 172/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 173/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 174/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0017
# Epoch 175/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0016
# Epoch 176/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0016
# Epoch 177/200
# 76/76 [==============================] - 0s 5ms/sample - loss: 0.0015
# Epoch 178/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0019
# Epoch 179/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0018
# Epoch 180/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0016
# Epoch 181/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0016
# Epoch 182/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0016
# Epoch 183/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0015
# Epoch 184/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0016
# Epoch 185/200
# 76/76 [==============================] - 0s 6ms/sample - loss: 0.0016
# Epoch 186/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0015
# Epoch 187/200
# 76/76 [==============================] - 0s 4ms/sample - loss: 0.0016
# Epoch 188/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0018
# Epoch 189/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0016
# Epoch 190/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0017
# Epoch 191/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0015
# Epoch 192/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0015
# Epoch 193/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 194/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 195/200
# 76/76 [==============================] - 0s 2ms/sample - loss: 0.0016
# Epoch 196/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0015
# Epoch 197/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0015
# Epoch 198/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0015
# Epoch 199/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0015
# Epoch 200/200
# 76/76 [==============================] - 0s 3ms/sample - loss: 0.0015

# %%
x = ktestX[0]
x = x[np.newaxis,:]

preds = []
for i in range(len(testY)):
    p = get_predictions(model,None,x)[0]
    x = np.hstack((x[:,1:,:], p[np.newaxis, np.newaxis,:])) # YOUR CODE HERE
    preds.append(p[0])
preds = np.r_[preds]

# %%
sy, spreds = get_predictions(model, scaler, ktrainX, [trainY])

# %%
plt.figure(figsize=(20,5))
plt.plot(range(len(sy),len(sy)+len(testY)), scaler.inverse_transform(testY.reshape(-1,1))[:,0], lw=5, alpha=.2, color="red")
plt.plot(range(len(sy),len(sy)+len(testY)), scaler.inverse_transform(preds.reshape(-1,1))[:,0], lw=2, color="red")
plt.plot(sy, lw=5, alpha=.5, color="blue")
plt.plot(spreds, lw=2, color="blue")
plt.grid()

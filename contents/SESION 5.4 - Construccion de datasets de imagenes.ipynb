# %%
import tensorflow as tf
from time import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mlutils
# %matplotlib inline

# %% [markdown]
# ## Imágenes desde ficheros
#
# ref https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html

# %% [markdown]
# ### descargamos imágenes de dos queries en google

# %%
# !pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading https://files.pythonhosted.org/packages/18/ed/0319d30c48f3653802da8e6dcfefcea6370157d10d566ef6807cceb5ec4d/google_images_download-2.8.0.tar.gz
# Collecting selenium (from google_images_download)
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 11.9MB/s ta 0:00:01    29% |█████████▍                      | 266kB 1.8MB/s eta 0:00:01    71% |██████████████████████▉         | 645kB 14.9MB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /home/user/.conda/envs/p37/lib/python3.7/site-packages (from selenium->google_images_download) (1.25.2)
# Building wheels for collected packages: google-images-download
#   Building wheel for google-images-download (setup.py) ... done
#   Stored in directory: /home/user/.cache/pip/wheels/1f/28/ad/f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.8.0 selenium-3.141.0

# %%
downloads = "/tmp/downloads"
traintest_imgs = "/tmp/imgs"

train_pct = .7

# %%
# !rm -rf $downloads
# !mkdir $downloads

# %%
cfg="""
{
    "Records": [
        {
            "keywords": "car",
            "format": "jpg",
            "limit": 50,
            "type": "photo",
            "size": "medium",
            "output_directory": "%s"
        },
        {
            "keywords": "truck",
            "format": "jpg",
            "limit": 50,
            "type": "photo",
            "size": "medium", 
            "output_directory": "%s"
        }
    ]
}
"""%(downloads, downloads)

# %%
with open(downloads+"/cfg.txt", "w") as f:
    f.write(cfg)

# %%
# !googleimagesdownload --config_file $downloads/cfg.txt
# Out:
# Item no.: 1 --> Item name = car
# Evaluating...
# Starting Download...
# Completed Image ====> 1.592f4169b74af41b008b5977-750-563.jpg
# Completed Image ====> 2.heres-why-the-mclaren-720s-worth-280000-is-a-difficult-car-to-love.jpg
# Completed Image ====> 3.mazda-vision-coupe-wins-2018-concept-car-of-the-year-4.jpg
# Completed Image ====> 4.Lam1_trans_NvBQzQNjv4BqnAdySV0BR-4fDN_-_p756cVfcy8zLGPV4EhRkjQy7tg.jpg
# Completed Image ====> 5.911-road-3629a.jpg
# Completed Image ====> 6._105855160_c_two-studio-image-front.jpg
# Completed Image ====> 7.performance.jpg
# Completed Image ====> 8.dfb51e2e4be24a07b71cbf021a81d6d3.jpg
# Completed Image ====> 9.https%3A%2F%2Fblogs-images.forbes.com%2Fericadams%2Ffiles%2F2019%2F04%2FDSC03157-1200x675.jpg
# Completed Image ====> 10.McLaren-Senna-car-price-new-2018-890981.jpg
# Completed Image ====> 11.jaguarf-pace.jpg
# Completed Image ====> 12._100284183_hi044452539.jpg
# Completed Image ====> 13.j1qtl37vkiw9nzefmkmw.jpg
# URLError on an image...trying next one... Error: HTTP Error 403: Forbidden
# Completed Image ====> 14.ms_tw.jpg
# Completed Image ====> 15.biomega-electric-car-concept-design-technology-vehicle_dezeen_2364_hero2-852x479.jpg
# Completed Image ====> 16.2018-monterey-2019-bugatti-divo-5-1200x630-c-ar1.91.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 17.ssc-tuatara.jpg
# Completed Image ====> 18.105340766-1532017490887v9-l0kjq.jpg
# Completed Image ====> 19.181126144412-04-gm-car-models-112618-exlarge-169.jpg
# Completed Image ====> 20.mercedes-amg_a35_mercedes-amg-a35-sedan_2020-1553631895931.jpg
# Completed Image ====> 21.front-left-side-47.jpg
# Completed Image ====> 22.gallardo-0638.jpg
# Completed Image ====> 23.AppleCarFront34_v003-780x439-780x439.jpg
# Completed Image ====> 24.vw-up-autosferraz-grupoB.jpg
# Completed Image ====> 25.205fa11c-c8aa-4d04-adbb-8a9cd85e8fb5.jpg
# Completed Image ====> 26.3800.jpg
# Completed Image ====> 27.hqdefault.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 28.img812810844-1551980833760.jpg
# Completed Image ====> 29.2019_kia_stinger_angularfront.jpg
# Completed Image ====> 30.citroen-19-19-concept.jpg
# Completed Image ====> 31.18ToyAygxpla5drRedFL_800.jpg
# Completed Image ====> 32.car_hatch.jpg
# Completed Image ====> 33.b756cf6e-fba3-483f-9800-c7eaa9cb61d4.jpg
# Completed Image ====> 34.59f3b183bcf93d1e008b548d-750-563.jpg
# Completed Image ====> 35.406638.jpg
# Completed Image ====> 36._105917230_bugatti_bbc.jpg
# Completed Image ====> 37.group-a-kia-picanto.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 38.renault-concept-car-014.jpg
# Completed Image ====> 39.microlino_fraumunster_web_001.jpg
# Completed Image ====> 40.636652589481890470-10Chevrolet-Corvette.JPG
# Wrong image format returned. Skipping...
# Completed Image ====> 41.228872.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 42.malagacar-office.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 43.methode%2Ftimes%2Fprod%2Fweb%2Fbin%2F696b3456-abbf-11e8-aa49-f23497b9293e.jpg
# Completed Image ====> 44.img_LTE-car.jpg
# Completed Image ====> 45.used-car-offer-2.jpg
# Completed Image ====> 46.MV5BMzMwYWZkZjctZTU5Ny00MDNiLTlkMmYtNzkyODMwMGUxYzA2XkEyXkFqcGdeQXVyNzU1NzE3NTg@._V1_CR0,45,480,270_AL_UX477_CR0,0,477,268_AL_.jpg
# Completed Image ====> 47.audi_a3_audi-a3-sedan_2019-1552084281910.jpg
# Completed Image ====> 48.harrier-pv-landing-banner-mob.jpg
# Completed Image ====> 49.Showcar-3-760x380.jpg
# Completed Image ====> 50.C-HR%20Hyrbid%202019%204470a.jpg
#
# Errors: 7
#
#
# Everything downloaded!
# Total errors: 7
# Total time taken: 47.07740259170532 Seconds
#
# Item no.: 1 --> Item name = truck
# Evaluating...
# Starting Download...
# Completed Image ====> 1.volvo-truck-autonomous_T2018_0314-1-1068x601.jpg
# Completed Image ====> 2.2606878260_W_S.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 3.20181119_truck.jpg
# Completed Image ====> 4.163649.jpg
# Completed Image ====> 5.thor-trucks-road.jpg
# IOError on an image...trying next one... Error: The read operation timed out
# Completed Image ====> 6.truck-brian-california.jpg
# Completed Image ====> 7.truck-highway-ribbon-fit.jpg
# Wrong image format returned. Skipping...
# Wrong image format returned. Skipping...
# Completed Image ====> 8.G-3_Resources_LLC_Truck.jpg
# Completed Image ====> 9.light-trucks.jpg
# Completed Image ====> 10.prima.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 11.42641575-1-f.jpg
# Completed Image ====> 12.960x0.jpg
# Completed Image ====> 13.pacLease-truck5.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 14.cc_2019cht300002_02_640_gaz.jpg
# Completed Image ====> 15.1541468747198.jpg
# Completed Image ====> 16.cleantruckspage.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 17.carroceria-camion-mon-tech-m-truck-20-019-003.jpg
# Completed Image ====> 18.1860x1050-sustainable-truck-year-2018-newsintro.jpg
# Completed Image ====> 19.10259413ActivitySheetImage.jpg
# Completed Image ====> 20.20170321021854-11.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 21.tesla-pickup-truck-1.jpg
# Completed Image ====> 22.dumper-truck-500x500.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 23.https%3A%2F%2Fblogs-images.forbes.com%2Fsebastianblanco%2Ffiles%2F2019%2F04%2Ftoyota-hydrogen-semi-1200x679.jpg
# Wrong image format returned. Skipping...
# URLError on an image...trying next one... Error: HTTP Error 403: Forbidden
# Completed Image ====> 24.vera-autonomous-truck.jpg
# Completed Image ====> 25.V-CargoVan.jpg
# Completed Image ====> 26.Transformers-Optimus-Truck-Driving-Experience-Day-1920x1080-resize.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 27.usps-motiv-power-e450-delivery-truck-for-fresno-california_100691314_l.jpg
# Completed Image ====> 28.2018_11_R1T_15-800x533.jpg
# Completed Image ====> 29.cascadia-rotated-500x300.jpg
# Completed Image ====> 30.1558115240-2019-ram-2500hd-1558115235.jpg
# Completed Image ====> 31.fatigue_monitor.jpg
# Completed Image ====> 32.dakota.jpg
# Completed Image ====> 33.zanella-force-truck-3.jpg
# Completed Image ====> 34.4261014_1.jpg
# Completed Image ====> 35.6cf32312-d0f6-4631-9850-4f950040fd7a-2019_Ram_1500.JPG
# Completed Image ====> 36.file-20180723-189310-y111iu.jpg
# Completed Image ====> 37.ca44038c1a6a47768591ec154adf8250_684x384.jpg
# Wrong image format returned. Skipping...
# Wrong image format returned. Skipping...
# Completed Image ====> 38.2019-ram-3500%20crew%20cab-frontside_ra35ct1901.jpg
# Completed Image ====> 39.Ford-Trucks-F-MAX-2019.jpg
# Completed Image ====> 40.DSC_0885.jpg
# Completed Image ====> 41.local-deliveries-hero.jpg
# Completed Image ====> 42.pickup-truck-jpg-1556033545.jpg
# Completed Image ====> 43.au-budget-trucks-deals-overnight-900x600.jpg
# Completed Image ====> 44.tesla-pickup-heavy-duty-e1550234900506.jpg
# Completed Image ====> 45.bharatbenz-rigid-tractor-tipper-653x435.jpg
# Completed Image ====> 46.300.jpg
# Wrong image format returned. Skipping...
# Completed Image ====> 47.hqdefault.jpg
# Completed Image ====> 48.foison-truck-small.jpg
# Completed Image ====> 49.SCC-Truck.jpg
# Completed Image ====> 50.faszination-show-truck-header.jpg
#
# Errors: 15
#
#
# Everything downloaded!
# Total errors: 22
# Total time taken: 121.10385847091675 Seconds

# %% [markdown]
# ### revisamos las imágenes y eliminamos las defectuosas

# %%
from skimage import io
files = !find $downloads -type f
for fname in files:
    if fname!=downloads+"/cfg.txt":
        print (".", end="")
        try:
            io.imread(fname)
        except:
            print ("\nremoving",fname,"as cannot be read\n")
            # !rm $fname
# Out:
# .....................
# removing /tmp/downloads/car/4.Lam1_trans_NvBQzQNjv4BqnAdySV0BR-4fDN_-_p756cVfcy8zLGPV4EhRkjQy7tg.jpg as cannot be read
#
# ..........................................
# removing /tmp/downloads/truck/14.cc_2019cht300002_02_640_gaz.jpg as cannot be read
#
# .....................................

# %% [markdown]
# ### organizamos las imágenes en train y en test

# %%
classdirs = !find $downloads -type d
classdirs = [i.split("/")[-1] for i in classdirs if i!=downloads]
print (classdirs)
# Out:
# ['car', 'truck']

# %%
# !rm -rf $traintest_imgs

# %%
for classdir in classdirs:
    print (classdir)
    print ("    splitting files ... ", end=" ")
    files = !find $downloads/$classdir -type f
    files = np.r_[files]
    n_train = int(len(files)*train_pct)
    files = np.random.permutation(files)
    files_train = files[:n_train]
    files_test  = files[n_train:]
    # !mkdir -p $traintest_imgs/train/$classdir
    # !mkdir -p $traintest_imgs/test/$classdir
    print ("copying files")
    for f in files_train:
        # !cp $f $traintest_imgs/train/$classdir
    for f in files_test:
        # !cp $f $traintest_imgs/test/$classdir
# Out:
# car
#     splitting files ...  copying files
# truck
#     splitting files ...  copying files

# %% [markdown]
# ### sanity check 1

# %%
for classdir in classdirs:
    print (classdir)
    files = !find  $traintest_imgs/train/$classdir -type f
    print ("      ",len(files), "train images")
    files = !find  $traintest_imgs/test/$classdir -type f
    print ("      ",len(files), "test images")
# Out:
# car
#        34 train images
#        15 test images
# truck
#        34 train images
#        15 test images

# %% [markdown]
# ### sanity check 2
#
# see [ImageGenerator](https://keras.io/preprocessing/image/)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
datagen = ImageDataGenerator(rescale=1./255, fill_mode='nearest')
batch_size = 10
img_size = 32
train_generator_fn = lambda: datagen.flow_from_directory(
        traintest_imgs+"/train",  # this is the target directory
        target_size=(img_size, img_size),  # all images will be resized to 150x150
        batch_size=batch_size,
        interpolation = "bilinear",
        class_mode='binary') 

test_generator_fn = lambda: datagen.flow_from_directory(
        traintest_imgs+"/test",  # this is the target directory
        target_size=(img_size, img_size),  # all images will be resized to 150x150
        batch_size=batch_size,
        interpolation = "bilinear",
        class_mode='binary')

# %%
for imgs,labels in train_generator_fn():
    if np.random.random()>.5:
        break
mlutils.show_labeled_image_mosaic(imgs, labels)
# Out:
# Found 68 images belonging to 2 classes.

# %% [markdown]
# ### train keras!!!

# %%
def get_conv_model_A(num_classes, img_size=32, compile=True):
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print ("using",num_classes,"classes")
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(15,(10,10), activation="relu")(inputs)
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(64, activation=tf.nn.relu)(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
    return model

# %%
num_classes = len(classdirs)
model = get_conv_model_A(num_classes, img_size=img_size)

model.fit_generator(
        train_generator_fn(),
        steps_per_epoch=1000 // batch_size,
        epochs=3,
        validation_data=test_generator_fn(),
        validation_steps=400 // batch_size)
# Out:
# using 2 classes
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/user/.conda/envs/p37/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Found 68 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.
# Epoch 1/3
# 3/3 [==============================] - 1s 246ms/step - loss: 0.6503 - acc: 0.6333
# 7/7 [==============================] - 2s 233ms/step - loss: 0.7189 - acc: 0.4265 - val_loss: 0.6503 - val_acc: 0.6333
# Epoch 2/3
# 3/3 [==============================] - 1s 247ms/step - loss: 0.6696 - acc: 0.7333
# 7/7 [==============================] - 1s 212ms/step - loss: 0.6417 - acc: 0.6324 - val_loss: 0.6696 - val_acc: 0.7333
# Epoch 3/3
# 3/3 [==============================] - 1s 242ms/step - loss: 0.6276 - acc: 0.6333
# 7/7 [==============================] - 1s 200ms/step - loss: 0.5825 - acc: 0.8824 - val_loss: 0.6276 - val_acc: 0.6333

# %% [markdown]
# ### predictions

# %%
def show_preds(x, preds):
    for i  in np.random.permutation(range(len(preds)))[:4]:
        plt.figure(figsize=(5,2.5))
        plt.subplot(122)
        plt.imshow(x[i])
        plt.axis("off")
        plt.subplot(121)
        plt.bar(np.arange(2), preds[i], color="blue", alpha=.5, label="prediction")
        plt.bar(np.arange(2), np.eye(2,2)[int(y[i])], color="red", alpha=.5, label="label")
        plt.xticks(range(2), range(2), rotation="vertical");
        plt.xlim(-.5,1.5);
        plt.legend(loc='upper center', bbox_to_anchor=(0.5, +1.35),ncol=5)

# %%
for x,y in test_generator_fn():
    if np.random.random()>.7:
        break
        
preds = model.predict(x)
mlutils.show_preds(x, y, preds)
# Out:
# Found 30 images belonging to 2 classes.
